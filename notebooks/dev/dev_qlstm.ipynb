# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df_yf = pd.read_parquet('E:\\fyp_qnn\\data\\yfinance\\AAPL.parquet', engine='pyarrow')['Close']
dataset = df_yf.values
df_train, df_test = train_test_split(dataset, test_size=0.2, shuffle=False)
print(df_train.shape, df_test.shape)
# Out:
# (828,) (208,)

# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parent.parent.parent))

# %%
from fyp_qnn.reproduction.qlstm.data_utils import create_datasets

# %%
df_yf = pd.read_parquet('E:\\fyp_qnn\\data\\yfinance\\AAPL.parquet', engine='pyarrow')

# %%
create_datasets(df_yf, test_size=0.2)
# Out:
# E:\fyp_qnn\fyp_qnn\reproduction\qlstm\data_utils.py:33: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method='ffill').dropna()
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 create_datasets(df_yf, test_size=0.2)
#
# File E:\fyp_qnn\fyp_qnn\reproduction\qlstm\data_utils.py:39, in create_datasets(df, window_size, target, sequence_length, test_size)
#      37 features = df.columns
#      38 df_train, df_test = train_test_split(df['Close_norm'].values, test_size=test_size, random_state=42, shuffle=False)
# ---> 39 train_dataset = SequenceDataset(
#      40     df_train,
#      41     target=target,
#      42     features=features,
#      43     sequence_length=sequence_length
#      44 )
#      45 test_dataset = SequenceDataset(
# ...
